# %%
import nltk
import math

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gadwa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gadwa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
S1 = "Northern cardinals are known for their beautiful, melodic songs, which both males and females sing."
#S2 = "Northern cardinals are known for their beautiful, melodic songs, which they use to communicate with mates, establish territory, and signal alarms to other birds."
#S2 = "Northern cardinals are known for their beautiful, melodic songs, which they use to communicate with mates, establish territory, and signal alarms to other birds."

# ChatGPT
# 10
#S2 = "Northern cardinals are known for their beautiful, melodic songs, which they use to communicate with mates, establish territory, and ward off intruders."

#Copilot
#prompt:7 words
#S2 ="Northern cardinals are known for their beautiful, striking plumage and vibrant red coloration, especially in males."
# rest: Their distinct, melodic songs and whistles add to their charm, making them a favorite among birdwatchers and nature lovers. These birds are also admired for their devotion to their mates, often engaging in affectionate behaviors like feeding each other. Have you ever spotted one in the wild?"
#prompt: 8 words
#S2 = "Northern cardinals are known for their beautiful, melodic songs that brighten up forests and backyards alike." 
#rest: Their whistles and warbles are not just pleasing to the ear but also serve as important communication tools, helping them mark territory and attract mates. These vibrant red songbirds have a rich, musical repertoire that makes them one of the most recognizable and beloved birds in North America."
#prompt: 9 words
#S2 = "Northern cardinals are known for their beautiful, melodic songs, which brighten woodlands and backyards alike with their rich whistles and cheerful warbles."
#rest: These striking red songbirds use their vocal talents to communicate, mark territory, and attract mates, making their music an essential part of their daily lives."
# 10
#S2 = "Northern cardinals are known for their beautiful, melodic songs, which are rich, varied, and often used to communicate territory boundaries or attract mates."

#Gemini
#prompt:7 words
#S2 ="Northern cardinals are known for their beautiful red plumage in males and reddish-brown plumage in females, as well as their distinctive crest and melodious songs."
#prompt: 8 words
#S2 = "Northern cardinals are known for their beautiful, melodic songs."
#prompt: 9 words
#S2 = "Northern cardinals are known for their beautiful, melodic songs, often described as clear, whistling phrases that can vary greatly and are sung by both males and females."
# 10
S2 = "Northern cardinals are known for their beautiful, melodic songs, which often consist of clear whistles, trills, and chirps, and are sung by both males and females, though the male's song is typically more complex and used for attracting mates and defending territory."

# %%
# human-written sentence
S1 = "Since the employee was on vacation, there was probably nothing else he could do."

#ChatGPT
# 7 words
#S2 = "Since the employee was on vacation, there was a temporary reassignment of their duties to ensure all tasks were completed on schedule."
# 8
#S2 = "Since the employee was on vacation, there was a temporary redistribution of their responsibilities among team members."
# 9
#S2 = "Since the employee was on vacation, there was probably a delay in responding to emails and completing assigned tasks."
# 10
#S2 = "Since the employee was on vacation, there was probably nothing urgent that required their immediate attention."

#Copilot

# 7 words
#S2 = "Since the employee was on vacation, there was a temporary gap in their responsibilities."

# full message: Sure! Here are a few ways to complete your sentence:

#"Since the employee was on vacation, there was a temporary gap in their responsibilities."

#"Since the employee was on vacation, their coworkers had to cover their tasks."

#"Since the employee was on vacation, the office felt a little quieter than usual."

#Would you like me to tailor the completion to a specific context? 

# 8 words
#S2 = "Since the employee was on vacation, there was a noticeable gap in productivity, but the rest of the team worked together to ensure everything ran smoothly."
# full message: a noticeable gap in productivity, but the rest of the team worked together to ensure everything ran smoothly. Or perhaps there was a peaceful silence where the usual chatter once was! It all depends on the employee—what kind of presence do you think they had?

# 9
#S2 = "Since the employee was on vacation, there was probably a temporary gap in their responsibilities, requiring colleagues to step in or tasks to be put on hold until their return."
# full: Since the employee was on vacation, there was probably a temporary gap in their responsibilities, requiring colleagues to step in or tasks to be put on hold until their return. Hopefully, it was a smooth transition—and maybe even a well-earned break for them! Is this part of a larger piece you're working on? I’d be happy to help refine it.

#10
#S2 = "Since the employee was on vacation, there was probably nothing urgent that required their immediate attention."
# (same as ChatGPT 10)

#Gemini
# 7 words
#S2 = "Since the employee was on vacation, there was no one to answer the phone in their department."
#8
#S2 = "Since the employee was on vacation, there was no one to answer the phone, so the customer had to leave a message."
# 9
#S2 = "Since the employee was on vacation, there was probably no one to answer the phone immediately."
#10
S2 = "Since the employee was on vacation, there was probably nothing urgent requiring immediate attention."

# %%
# 10 from ChatGPT

#Astronomy: Jupiter is the largest planet in our solar system and has a powerful magnetic field.
ah = "Please complete the following sentence: Jupiter is the largest planet in our solar system and has a powerful magnetic field."

S1 = "Jupiter is the largest planet in our solar system and has a powerful magnetic field."

# completetions: ChatGPT
# 7
S2 = "Jupiter is the largest planet in our solar system."
# 8
S2 = "Jupiter is the largest planet in our solar system."
# 9
S2 = "Jupiter is the largest planet in our solar system, known for its massive size, powerful storms like the Great Red Spot, and its many moons, including the four largest—Io, Europa, Ganymede, and Callisto."
#10
S2 = "Jupiter is the largest planet in our solar system and is known for its massive size, powerful magnetic field, and iconic Great Red Spot, a giant storm that has raged for centuries."

# Copilot
#7
S2 = "Jupiter is the largest planet in our solar system."
#8
S2 = "Jupiter is the largest planet in our solar system, boasting a massive diameter of about 139,820 kilometers (86,881 miles) and a powerful gravitational pull that influences everything around it."
#9
S2 = "Jupiter is the largest planet in our solar system, boasting a massive diameter of about 143,000 kilometers (about 89,000 miles) and a powerful gravitational influence."
#10
S2 = "Jupiter is the largest planet in our solar system and a gas giant primarily composed of hydrogen and helium."

# Gemini
#7
S2 = "Jupiter is the largest planet in our solar system."
#8
S2 = "Jupiter is the largest planet in our solar system."
#9
S2 = "Jupiter is the largest planet in our solar system, a gas giant with a swirling atmosphere and a prominent Great Red Spot."
#10
S2 = "Jupiter is the largest planet in our solar system and is a gas giant, primarily composed of hydrogen and helium."

#History: The Great Wall of China was built over centuries to protect against invasions from nomadic tribes.

ah = "Please complete the following sentence: The Great Wall of China was built over centuries to protect against invasions from nomadic tribes.""
S3 = "The Great Wall of China was built over centuries to protect against invasions from nomadic tribes."

#ChatGPT
#8
S4 = "The Great Wall of China was built over several centuries by various dynasties to protect Chinese states and empires from invasions and raids by nomadic tribes from the north."
#9
S4 = "The Great Wall of China was built over centuries to protect Chinese states and empires from invasions and raids by various nomadic groups from the north."
#10
S4 = "The Great Wall of China was built over centuries to protect Chinese states and empires from invasions and raids by various nomadic groups from the north."
#11
S4 = "The Great Wall of China was built over centuries to protect Chinese states and empires from invasions and raids by various nomadic groups from the north."

#Copilot
#8
S4 = "The Great Wall of China was built over centuries, spanning multiple dynasties, with construction beginning as early as the 7th century BCE and continuing through the Ming dynasty in the 17th century."
#9
S4 = "The Great Wall of China was built over centuries, evolving from scattered fortifications into a massive defense system stretching thousands of miles, protecting ancient dynasties from invasions and unifying regions under a singular architectural marvel."
#10
S4 = "The Great Wall of China was built over centuries to serve as a formidable defense against invasions and raids from northern nomadic groups, particularly the Mongols."
#11
S4 = "The Great Wall of China was built over centuries to protect Chinese states and empires from invasions and raids by nomadic groups from the north."

# Gemini
#8
S4 = "The Great Wall of China was built over centuries, by various dynasties, to protect against invasions from the north."
#9
S4 = "The Great Wall of China was built over centuries by various dynasties as a series of fortifications against invasions and to delineate territorial boundaries."
#10
S4 = "The Great Wall of China was built over centuries to protect the Chinese Empire from invaders and to delineate its northern border."
#11
S4 = "The Great Wall of China was built over centuries to protect the Chinese Empire from invaders and to delineate its northern border."

#Technology: Artificial intelligence is rapidly transforming industries such as healthcare, finance, and education.

ah = "Please complete the following sentence: Artificial intelligence is rapidly transforming industries such as healthcare, finance, and education."
S5 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, and education."

#ChatGPT
#6
S6 = "Artificial intelligence is rapidly transforming industries by automating processes, enhancing decision-making, and enabling the development of innovative products and services across sectors such as healthcare, finance, manufacturing, and transportation."
#7
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, and transportation by automating processes, enhancing decision-making, and unlocking new levels of efficiency and innovation."
#8
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, transportation, and retail by automating processes, enhancing decision-making, and enabling new capabilities."

#Copilot
#6
S6 = "Artificial intelligence is rapidly transforming industries by automating complex processes, enhancing decision-making with data-driven insights, and fostering innovation in fields ranging from healthcare and finance to manufacturing and entertainment."
#7
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, and retail by automating processes, enhancing decision-making, and revolutionizing customer experiences."
#8
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, and retail, revolutionizing processes through automation, predictive analytics, and enhanced decision-making capabilities."

#Gemini
#6
S6 = "Artificial intelligence is rapidly transforming industries by automating tasks, improving efficiency, enabling new products and services, and providing deeper insights from data."
#7
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, transportation, and education, leading to increased efficiency, automation, and the development of innovative products and services."
# note: featured a reference to https://cadilamo.info/2024/05/24/what-are-the-future-software-technologies/ with a "1" near automation
#8
S6 = "Artificial intelligence is rapidly transforming industries such as healthcare, finance, manufacturing, transportation, and education."


#Biology: Photosynthesis is the process by which green plants convert sunlight into energy.

ah = "Please complete the following sentence: Photosynthesis is the process by which green plants convert sunlight into energy."
S7 = "Photosynthesis is the process by which green plants convert sunlight into energy."

#ChatGPT
#6
S8 = "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy, usually from the sun, into chemical energy in the form of glucose, using carbon dioxide and water."
#7
S8 = "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy, usually from the sun, into chemical energy stored in glucose, using carbon dioxide and water."
#8
S8 = "Photosynthesis is the process by which green plants use sunlight to convert carbon dioxide and water into glucose and oxygen."

# Copilot
#6
S8 = "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy into chemical energy, using sunlight to synthesize nutrients from carbon dioxide and water."
#7
S8 = "Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy into chemical energy, producing oxygen and glucose."
#8
S8 = "Photosynthesis is the process by which green plants convert light energy into chemical energy, using sunlight to transform carbon dioxide and water into glucose and oxygen."
# this is the 1st time I turned personalization off for Copilot

#Gemini
#6
S8 = "Photosynthesis is the process by which green plants, algae, and some bacteria use sunlight, water, and carbon dioxide to create glucose (a type of sugar) and oxygen."
#7
S8 = "Photosynthesis is the process by which green plants and some other organisms use sunlight to synthesize foods with the help of chlorophyll."
# note: featured a reference with a link to https://www.vproexpert.com/get-smarter-with-chatgpt-top-5-study-commands-for-personalized-learning-with-ai/ and a "1" was placed superscripted to the word "chlorophyll"
#8
S8 = "Photosynthesis is the process by which green plants use sunlight, water, and carbon dioxide to create their own food (glucose) and release oxygen as a byproduct."


#Literature: Shakespeare’s Hamlet explores themes of revenge, madness, and existential uncertainty.

ah = "Please complete the following sentence: Shakespeare’s Hamlet explores themes of revenge, madness, and existential uncertainty."
S9 = "Shakespeare’s Hamlet explores themes of revenge, madness, and existential uncertainty."

#ChatGPT
#5
S10 = "Shakespeare’s Hamlet explores themes of revenge, madness, mortality, and the complexity of human emotion and morality."
#6
S10 = "Shakespeare’s Hamlet explores themes of revenge, mortality, madness, and the moral consequences of action and inaction." 
#7
S10 = "Shakespeare’s Hamlet explores themes of revenge, madness, mortality, and the complexity of human emotion and moral corruption."

#Copilot
#5
S10 = "Shakespeare’s Hamlet explores themes of revenge, mortality, madness, betrayal, and the complexity of human nature."
#6
S10 = "Shakespeare’s Hamlet explores themes of revenge, grappling with the psychological and moral consequences of vengeance as Prince Hamlet wrestles with the duty to avenge his father’s murder."
#7
S10 = "Shakespeare’s Hamlet explores themes of revenge, madness, and the uncertainty of existence, as the protagonist grapples with moral dilemmas, political intrigue, and the psychological toll of grief and betrayal."

#Gemini
#5
S10 = "Shakespeare's Hamlet explores themes of revenge, grief, madness (both real and feigned), corruption, mortality, and the uncertainty of existence."
#6
S10 = "Shakespeare's Hamlet explores themes of revenge, mortality, madness, corruption, and the complexities of human action and inaction."
#7
S10 = "Shakespeare's Hamlet explores themes of revenge, madness, mortality, and the corrupting nature of power."


#Music: Beethoven continued to compose remarkable music even after he lost his hearing.

ah = "Please complete the following sentence: Beethoven continued to compose remarkable music even after he lost his hearing."
S11 = "Beethoven continued to compose remarkable music even after he lost his hearing."

#ChatGPT
#6
S12 = "Beethoven continued to compose remarkable music even after losing his hearing, demonstrating extraordinary resilience and genius."
#7
S12 = "Beethoven continued to compose remarkable music even after he became completely deaf, demonstrating extraordinary resilience and genius."
#8
S12 = "Beethoven continued to compose remarkable music even after he began to lose his hearing, ultimately creating some of his most celebrated works while completely deaf."

#Copilot
#6
S12 = "Beethoven continued to compose remarkable music despite losing his hearing, proving that passion and genius transcend physical limitations."
#7
S12 = "Beethoven continued to compose remarkable music even after losing his hearing."
#8
S12 = "Beethoven continued to compose remarkable music even after he lost his hearing."

#Gemini
#6
S12 = "Beethoven continued to compose remarkable music even as his hearing progressively deteriorated, creating some of his most profound and innovative works in his later years."
#7
S12 = "Beethoven continued to compose remarkable music even after he began to lose his hearing."
#8
S12 = "Beethoven continued to compose remarkable music even after he began to lose his hearing."


#Geography: The Amazon River, flowing through South America, is one of the longest rivers in the world.

ah = "Please complete the following sentence: The Amazon River, flowing through South America, is one of the longest rivers in the world."
S13 = "The Amazon River, flowing through South America, is one of the longest rivers in the world."

#ChatGPT
#8
S14 = "The Amazon River, flowing through South America, is the second longest river in the world and the largest by discharge volume of water, supporting a vast and diverse ecosystem."
#9
S14 = "The Amazon River, flowing through South America, is one of the longest and most voluminous rivers in the world, supporting an incredibly diverse ecosystem."
#10
S14 = "The Amazon River, flowing through South America, is one of the longest and most voluminous rivers in the world, renowned for its vast biodiversity and critical role in the Earth's ecosystem."
#11
S14 = "The Amazon River, flowing through South America, is one of the longest and most voluminous rivers in the world, renowned for its vast biodiversity and crucial role in the global ecosystem."

#Copilot
#8
S14 = "The Amazon River, flowing through South America, is one of the longest and most powerful rivers in the world, stretching over 4,300 miles and carrying more water than any other river on Earth."
#9
S14 = "The Amazon River, flowing through South America, is one of the longest and most voluminous rivers in the world, teeming with biodiversity and shaping the landscapes and cultures of the continent."
#10
S14 = "The Amazon River, flowing through South America, is one of the longest and most voluminous rivers in the world."
#11
S14 = "The Amazon River, flowing through South America, is one of the longest and most powerful rivers in the world."

#Gemini
#8
S14 = "The Amazon River, flowing through South America, is the largest river in the world by discharge volume of water."
#9
S14 = "The Amazon River, flowing through South America, is one of the longest rivers in the world and holds the largest volume of freshwater discharge globally."
#10
S14 = "The Amazon River, flowing through South America, is one of the longest rivers in the world by discharge volume of water."
#11
S14 = "The Amazon River, flowing through South America, is one of the longest rivers in the world by discharge volume of water."


#Art: Vincent van Gogh's use of bold colors and expressive brushwork helped define Post-Impressionism.

ah = "Please complete the following sentence: Vincent van Gogh's use of bold colors and expressive brushwork helped define Post-Impressionism."
S15 = "Vincent van Gogh's use of bold colors and expressive brushwork helped define Post-Impressionism."

#ChatGPT
#6
S16 = "Vincent van Gogh's use of bold colors and expressive brushwork helped convey intense emotion and movement, setting his style apart as a cornerstone of post-impressionist art."
#7
S16 = "Vincent van Gogh's use of bold colors conveys intense emotion and energy, transforming ordinary subjects into powerful expressions of his inner world."
#8
S16 = "Vincent van Gogh's use of bold colors and expressive brushwork conveyed intense emotion and movement, helping to define the Post-Impressionist style."
#9
S16 = "Vincent van Gogh's use of bold colors and expressive brushwork captured intense emotion and movement, distinguishing his style as a cornerstone of post-impressionist art."

#Copilot
#6
S16 = "Vincent van Gogh's use of bold colors and expressive brushstrokes defines his distinctive style, conveying intense emotion and movement in his paintings."
#7
S16 = "Vincent van Gogh's use of bold colors was a defining characteristic of his artistic style, conveying deep emotion and intensity while revolutionizing the expressive possibilities of painting."
#8
S16 = "Vincent van Gogh's use of bold colors and expressive brushstrokes created a sense of emotional intensity and movement in his paintings, capturing the essence of his unique perspective on the world."
#9
S16 = "Vincent van Gogh's use of bold colors and expressive brushstrokes revolutionized Post-Impressionist painting, capturing raw emotion and psychological depth in his art."

#Gemini
#6
S16 = "Vincent van Gogh's use of bold brushstrokes and vibrant colors revolutionized post-impressionist painting, conveying intense emotion and a unique perspective on the world."
#7
S16 = "Vincent van Gogh's use of bold colors and thick impasto created a sense of emotional intensity and dynamism in his paintings."
#8
S16 = "Vincent van Gogh's use of bold colors and thick impasto created emotionally charged and visually striking paintings that continue to captivate viewers today."
#9
S16 = "Vincent van Gogh's use of bold colors and expressive brushstrokes created a sense of emotional intensity and dynamism in his paintings."


#Economics: Inflation occurs when the general price level of goods and services rises over time.

ah = "Please complete the following sentence: Inflation occurs when the general price level of goods and services rises over time."
S17 = "Inflation occurs when the general price level of goods and services rises over time."

#ChatGPT
#7
S18 = "Inflation occurs when the general price level of goods and services in an economy rises over a period of time, leading to a decrease in the purchasing power of money."
#8
S18 = "Inflation occurs when the general price level of goods and services in an economy rises over a period of time, reducing the purchasing power of money."
#9
S18 = "Inflation occurs when the general price level of goods and services in an economy rises over a period of time, reducing the purchasing power of money."
#10
S18 = "Inflation occurs when the general price level of goods and services in an economy rises over a period of time, reducing the purchasing power of money."

#Copilot
#7
S18 = "Inflation occurs when the general price level rises over a period of time, reducing the purchasing power of money."
#8
S18 = "Inflation occurs when the general price level of goods and services rises over a period of time, reducing the purchasing power of money."
#9
S18 = "Inflation occurs when the general price level of goods and services rises over time, reducing the purchasing power of money."
#10
S18 = "Inflation occurs when the general price level of goods and services rises over time, decreasing the purchasing power of money."

#Gemini
#7
S18 = "Inflation occurs when the general price level of goods and services in an economy increases over a period of time." 
#8
S18 = "Inflation occurs when the general price level of goods and services in an economy increases over a period of time."
#9
S18 = "Inflation occurs when the general price level of goods and services in an economy increases over a period of time, leading to a decline in the purchasing power of money. "
# note: featured a reference with a link to https://costsnews.com/2024/09/14/navigating-inflation-tips-for-managing-rising-costs/ and a "1" was placed superscripted to the word "decline"
#10
S18 = "Inflation occurs when the general price level of goods and services in an economy increases over a period of time."


#Psychology: Cognitive behavioral therapy helps individuals identify and change negative thought patterns.

ah = "Please complete the following sentence: Cognitive behavioral therapy helps individuals identify and change negative thought patterns."
S19 = "Cognitive behavioral therapy helps individuals identify and change negative thought patterns."

#ChatGPT
#5
S20 = "Cognitive behavioral therapy helps individuals identify and change negative thought patterns and behaviors that contribute to emotional distress."
#6
S20 = "Cognitive behavioral therapy helps individuals identify and challenge negative thought patterns and behaviors, replacing them with healthier, more constructive ways of thinking and acting." 
#7
S20 = "Cognitive behavioral therapy helps individuals identify and challenge negative thought patterns and behaviors, enabling them to develop healthier ways of thinking and coping."
#8
S20 = "Cognitive behavioral therapy helps individuals identify and change negative thought patterns and behaviors that contribute to emotional distress or maladaptive responses."

#Copilot
#5
S20 = "Cognitive behavioral therapy helps individuals identify and change negative thought patterns and behaviors, improving emotional regulation, coping strategies, and overall mental well-being."
#6
S20 = "Cognitive behavioral therapy helps individuals identify negative thought patterns and behaviors, allowing them to develop healthier coping strategies and positive changes."
#7
S20 = "Cognitive behavioral therapy helps individuals identify and challenge negative thought patterns, develop healthier coping mechanisms, and cultivate more constructive behaviors."
#8
S20 = "Cognitive behavioral therapy helps individuals identify and change negative thought patterns and behaviors that contribute to emotional distress, fostering healthier coping strategies and improved mental well-being."

#Gemini
#5
S20 = "Cognitive behavioral therapy helps individuals identify and change negative or unhelpful thought patterns and behaviors to improve their emotional well-being and functioning."
#6
S20 = "Cognitive behavioral therapy helps individuals identify negative or unhelpful thought patterns and behaviors and develop more effective coping mechanisms."
#7
S20 = "Cognitive behavioral therapy helps individuals identify and modify negative thought patterns and behaviors."
#8
S20 = "Cognitive behavioral therapy helps individuals identify and change negative or unhelpful thought patterns and behaviors."

# %%
# 10 from Copilot

#The Northern cardinal’s vivid red feathers serve as both a visual delight and a territorial warning to rivals.

#Jupiter’s Great Red Spot is a storm so massive that it could swallow Earth whole.

#Workplace dynamics often hinge on subtle, unspoken rules that shape interactions more than official policies do.

#Light pollution dims the brilliance of the night sky, making it harder to see stars that once guided explorers.

#The Fibonacci sequence appears in nature—from pinecones to galaxies—revealing a hidden mathematical harmony.

#Coffee-drinkers might be surprised to learn that their favorite beverage starts as a bright red fruit before roasting transforms it into the rich, aromatic beans they know.

#Despite their sluggish reputation, sloths have a strong grip, thanks to specialized tendons in their limbs.

#The Andromeda Galaxy is hurtling toward the Milky Way, destined to merge with us in a cosmic collision billions of years from now.

#A simple workplace gesture, like bringing a colleague their favorite snack, can foster camaraderie more effectively than formal team-building exercises.

#Some trees communicate through underground fungal networks, exchanging nutrients and chemical signals in a system dubbed the "wood wide web."

# %%
# 10 from Gemini

#The aroma of freshly baked bread filled the cozy kitchen, promising a delightful breakfast.

#Across the vast expanse of the night sky, countless stars twinkled like distant diamonds.

#Climate change is presenting significant challenges to ecosystems around the globe.

#The intricate details of the ancient Roman mosaics revealed a rich history and artistry.

#Learning a new language can open doors to different cultures and perspectives.

#A gentle breeze rustled the leaves in the trees, creating a soothing melody.

#Quantum physics explores the strange and fascinating world of subatomic particles.

#The vibrant colors of the coral reef teemed with diverse marine life.

#Effective communication is essential for building strong and lasting relationships.

#Technology continues to evolve at a rapid pace, shaping the way we live and work.

# %%
### human-written

#LG was also caught collecting and transmitting data without permission from users through its smart TVs.
ah = "Please complete the following sentence: LG was also caught collecting and transmitting data without permission from users through its smart TVs."

S21 = "LG was also caught collecting and transmitting data without permission from users through its smart TVs."

#ChatGPT
# 8
S22 = "LG was also caught collecting and transmitting data from its smart devices, including personal information and usage patterns, without proper consent or disclosure to users, raising concerns about privacy and data security."
#9
S22 = "LG was also caught collecting and transmitting data without users' consent through its Smart TVs."
#note: referenced a variety of sources
#10
S22 = "LG was also caught collecting and transmitting data without permission, potentially violating user privacy and raising concerns about data security practices within the company."
#11
S22 = "LG was also caught collecting and transmitting data without permission from users of its smart TVs."
#note: referenced a variety of sources

#Copilot
#8
S22 = "LG was found to be collecting and transmitting user data from its Smart TVs, even when users had disabled the data collection feature."
#note: ignored my sentence start
#9
S22 = "LG was caught collecting and transmitting data without user consent, particularly through its smart TVs, which were found to log viewing habits and send the data back to the company even when users had disabled data collection."
#10
S22 = "LG was found to be collecting and transmitting user data from its smart TVs without permission, even when users had disabled the data collection feature."
#11
S22 = "LG was caught collecting and transmitting data without permission from its smart TV users, logging their viewing habits and sending the information back to the company."
#note: all four included references

#Gemini
#8
S22 = "LG was also caught collecting and transmitting data from its smart TVs without user consent."
#9
S22 = "LG was also caught collecting and transmitting data without user consent."
#10
S22 = "LG was also caught collecting and transmitting data without permission from its smart TVs, logging users' viewing habits and even file names from connected USB drives without their explicit consent."
#11
S22 = "LG was also caught collecting and transmitting data without permission from its smart TV users, even when they had disabled data sharing options."


#The popular video-sharing website YouTube has had a problem with keeping spam from bots under control. 
ah = "Please complete the following sentence: The popular video-sharing website YouTube has had a problem with keeping spam from bots under control."

S23 = "The popular video-sharing website YouTube has had a problem with keeping spam from bots under control."

#ChatGPT
#8
S24 = "The popular video-sharing website YouTube has had a significant impact on the way people consume and share content, evolving from a simple platform for uploading videos to a global powerhouse for entertainment, education, and marketing."
#9
S24 = "The popular video-sharing website YouTube has had a problem with misinformation and harmful content spreading across its platform, despite its efforts to implement stricter content moderation policies and algorithms to address the issue."
#10
S24 = "The popular video-sharing website YouTube has had a problem with moderating harmful content, as well as managing misinformation, copyright infringement, and ensuring the safety of its users, particularly minors."
#11
S24 = "The popular video-sharing website YouTube has had a problem with keeping content moderation consistent, as it struggles to balance free speech with the need to remove harmful or inappropriate material."
#note: I received a 2nd response from this: "The popular video-sharing website YouTube has had a problem with keeping its content moderation policies consistent, leading to concerns about the spread of misinformation, harmful content, and the enforcement of community guidelines." 

#Copilot
#8
S24 = "The popular video-sharing website YouTube has had a remarkable impact on digital culture, entertainment, and even education."
#9
S24 = "YouTube has had a problem with various issues, including video loading errors, content availability problems, and even difficulties with uploading new videos and Shorts."
#note: ignored my first part and used references
#10
S24 = "The popular video-sharing website YouTube has had a problem with the challenges that come with managing a vast online platform!"
#11
S24 = "The popular video-sharing website YouTube has had a problem with keeping certain types of content in check, as it continuously works to balance creative freedom with policies that prevent misinformation, inappropriate material, and harmful content."

#Gemini
#8
S24 = "The popular video-sharing website YouTube has had a significant and multifaceted impact on global culture, entertainment, education, and communication."
#9
S24 = "The popular video-sharing website YouTube has had a problem with content moderation, leading to debates about censorship, misinformation, and the spread of harmful content."
#10
S24 = "The popular video-sharing website YouTube has had a problem with content moderation and the spread of misinformation."
#11
S24 = "The popular video-sharing website YouTube has had a problem with keeping inappropriate or harmful content off its platform."


#COBOL was the first high-level business language that was successful.
ah = "Please complete the following sentence: COBOL was the first high-level business language that was successful."

S25 = "COBOL was the first high-level business language that was successful."

#ChatGPT
#5
S26 = "COBOL was the first high-level programming language designed specifically for business data processing."
#6
S26 = "COBOL was the first high-level business programming language designed specifically for commercial data processing applications."
#7
S26 = "COBOL was the first high-level business language designed to be readable by non-programmers and widely used for commercial and administrative systems."

#Copilot
#5
S26 = "COBOL was one of the first high-level programming languages designed for business and finance applications."
#6
S26 = "COBOL was the first high-level business programming language designed specifically for commercial data processing."
#7
S26 = "COBOL was the first high-level business language designed for readability and ease of use, particularly in financial and administrative systems."

#Gemini
#5
S26 = "COBOL was the first high-level programming language widely used for business applications."
#6
S26 = "COBOL was the first high-level business programming language designed specifically for commercial data processing."
#7
S26 = "COBOL was the first high-level business language designed specifically for business data processing, enabling programs to be written in a readable English-like syntax that could run on different types of computer systems."


#Within the English used in the United States, there are many different dialects. 
ah = "Please complete the following sentence: Within the English used in the United States, there are many different dialects."

S27 = "Within the English used in the United States, there are many different dialects."

#ChatGPT
#6
S28 = "Within the English used in the legal profession, many terms have roots in Latin and have retained their traditional meanings over centuries."
#7
S28 = "Within the English used in the United States, regional dialects and vocabulary can vary significantly from one area to another."
#8
S28 = "Within the English used in the United States, regional dialects, cultural influences, and evolving social trends contribute to a rich and dynamic variation in vocabulary, pronunciation, and grammar."
#9
S28 = "Within the English used in the United States, there are numerous regional dialects that reflect the country's cultural and historical diversity."

#Copilot
#6
S28 = "Within the English used in the world today, variations in dialect, pronunciation, and vocabulary reflect the rich cultural and historical influences that shape the language."
#7
S28 = "If you’re thinking about how English is used within the United States, it could lead to a discussion about accents, vocabulary differences, or even how the language evolves over time." 
# note: Copilot did not want to just complete this sentence
#8
S28 = "Within the English used in the United States, you'll find a rich tapestry of regional dialects, unique expressions, and evolving language trends influenced by history, culture, and technology."
#9
S28 = "Within the English used in the United States, there exist numerous regional dialects and variations that shape communication and cultural identity."

#Gemini
#6
S28 = "Within the English used in the United States, you'll find regional variations in vocabulary and pronunciation."
#7
S28 = "Within the English used in the United States, there exists a fascinating tapestry of regional dialects, each with its own unique vocabulary, pronunciation, and grammatical nuances."
#8
S28 = "Within the English used in the United States, a rich tapestry of regional dialects, slang, and evolving vocabulary reflects the nation's diverse history, geography, and cultural influences."
#9
S28 = "Within the English used in the United States, there exists a rich tapestry of regional dialects and variations in pronunciation, vocabulary, and grammar, reflecting the diverse history and cultural influences of the country."


#Memristors do not introduce any energy to circuits that they are in and are therefore described as passive. 
ah = "Please complete the following sentence: Memristors do not introduce any energy to circuits that they are in and are therefore described as passive."

S29 = "Memristors do not introduce any energy to circuits that they are in and are therefore described as passive."

#ChatGPT
#9
S30 = "Memristors do not introduce any energy to circuits that they are part of, as they are passive components whose behavior depends on the history of voltage and current rather than active power delivery."
#10
S30 = "Memristors do not introduce any energy to circuits that they are part of, as they primarily function by storing and modulating electrical charge based on the history of voltage applied, without generating or dissipating energy themselves."
#11
S30 = "Memristors do not introduce any energy to circuits that they are integrated into; instead, they store and regulate electrical charge, contributing to the circuit's overall resistance without actively generating or dissipating energy."
#12
S30 = "Memristors do not introduce any energy to circuits that they are in, as they are passive components; instead, they store and recall energy based on the charge and flux linkage, allowing them to alter the resistance in response to the history of current flowing through them."

#Copilot
#9
S30 = "Memristors do not introduce any energy to circuits that operate solely based on passive components and resistive effects."
#10
S30 = "Memristors do not introduce any energy to circuits that they influence, as they solely regulate the flow of charge based on their memory-dependent resistance."
#11
S30 = "Memristors do not introduce any energy to circuits that they are part of, as they operate solely based on their inherent resistance and memory characteristics."
#12
S30 = "Memristors do not introduce any energy to circuits that they are in but rather regulate and store electrical charge based on their resistance state, which is influenced by previous electrical activity."

#Gemini
#9
S30 = "Memristors do not introduce any energy to circuits that operate in a purely resistive mode, where the voltage and current are linearly related at any given instant."
#10
S30 = "Memristors do not introduce any energy to circuits that they are a part of; instead, they dissipate energy like resistors, but their resistance depends on the history of the voltage or current applied to them."
#11
S30 = "Memristors do not introduce any energy to circuits that they are a part of."
#12
S30 = "Memristors do not introduce any energy to circuits that they are in; instead, they dissipate energy as heat, similar to resistors, and store information by changing their resistance based on the history of the current that has flowed through them."


# Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo Da Vinci's major accomplishments.
ah = "Please complete the following sentence: Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo Da Vinci's major accomplishments."

S31 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo Da Vinci's major accomplishments."

#ChatGPT
#8
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a biographical account of the life and achievements of Leonardo da Vinci, written as part of his larger work Lives of the Most Excellent Painters, Sculptors, and Architects."
#9
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological biography that offers an account of the life and achievements of Leonardo da Vinci, focusing on his artistic career, contributions to various fields, and his lasting influence on the Renaissance."
#10
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of the artist's life, detailing his early years, education, works, and achievements, while also offering insights into his character, intellectual pursuits, and artistic innovations."
#11
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's career, artistic achievements, and personal life, offering insights into his genius and contributions to the Renaissance, as well as his relationships with patrons and other artists."

#Copilot
#8
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a biographical account of Leonardo da Vinci's life and artistic achievements, written by Giorgio Vasari as part of his larger work, Lives of the Most Excellent Painters, Sculptors, and Architects."
#note: includes reference
#9
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's life and artistic achievements, detailing his training, major works, and influence on Renaissance art."
#10
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's artistic and intellectual development, interwoven with anecdotes that highlight his character, talents, and influence on Renaissance art."
#11
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's artistic and intellectual development, detailing his training, major works, and contributions to various fields, including painting, sculpture, engineering, and anatomy."
# note: all include references

#Gemini
#8
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a biographical account of the artist's life and work, often considered one of the earliest and most influential pieces of art historical writing."
#9
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of his life and artistic development, interspersed with anecdotes and assessments of his works."
#10
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's life and artistic development, interspersed with anecdotes, opinions, and interpretations of his work."
#11
S32 = "Giorgio Vasari's 'Life of Leonardo' is primarily a chronological account of Leonardo da Vinci's artistic and professional career, highlighting his major works, patrons, and significant events in his life."


#Laptops are typically much larger than smart cell phones, but laptops are also older.
ah = "Please complete the following sentence: Laptops are typically much larger than smart cell phones, but laptops are also older."

S33 = "Laptops are typically much larger than smart cell phones, but laptops are also older."

#ChatGPT
#7
S34 = "Laptops are typically much larger than smartphones, offering more screen space and processing power for complex tasks."
#8
S34 = "Laptops are typically much larger than smart cell phones, offering bigger screens, full-sized keyboards, and more powerful hardware for tasks like productivity, media editing, and gaming."
#9
S34 = "Laptops are typically much larger than smart cell phones, offering more powerful hardware, larger screens, and full-sized keyboards to support tasks like document editing, programming, and multitasking."
#10
S34 = "Laptops are typically much larger than smart cell phones, but they offer greater processing power, a larger display for multitasking, and a more comfortable typing experience for extended use."

#Copilot
#7
S34 = "Laptops are typically much larger than smartphones!"
#8
S34 = "Laptops are typically much larger than smart cell phones, and they often come with more powerful hardware, larger screens, and a physical keyboard for easier typing."
#9
S34 = "Laptops are typically much larger than smart cell phones, providing more screen space, a full-sized keyboard, and increased processing power for complex tasks."
#10
S34 = "Laptops are typically much larger than smart cell phones, but they offer a more expansive screen, a physical keyboard, and greater processing power, making them ideal for tasks that require multitasking, detailed work, or high-performance computing."

#Gemini
#7
S34 = "Laptops are typically much larger than smartwatches."
#8
S34 = "Laptops are typically much larger than smart cell phones."
#9
S34 = "Laptops are typically much larger than smart cell phones, offering a larger screen for viewing content and a more spacious keyboard for typing, though they sacrifice the extreme portability of a phone."
#10
S34 = "Laptops are typically much larger than smart cell phones, but they offer significantly more processing power and screen real estate for complex tasks."

#Much of the dark atmosphere in Hedda Gabler stems from Eilert Lovborg's presence.
ah = "Please complete the following sentence: Much of the dark atmosphere in Hedda Gabler stems from Eilert Lovborg's presence."

S35 = "Much of the dark atmosphere in Hedda Gabler stems from Eilert Lovborg's presence."

#ChatGPT
#6
S36 = "Much of the dark atmosphere in the novel stems from its bleak setting, morally ambiguous characters, and the constant sense of impending doom that permeates each scene."
#7
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the oppressive social expectations placed on Hedda and her growing sense of entrapment within a stifling domestic life."
#8
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the psychological tension between the characters, Hedda's repressed desires and manipulative behavior, and the stifling societal expectations that trap her in a life she neither chose nor desires."
#9
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the protagonist's psychological turmoil and the oppressive social constraints that limit her autonomy."

#Copilot
#6
S36 = "Much of the dark atmosphere in Gothic literature stems from themes of isolation, decay, and the supernatural."
#note: I received three examples for this, I picked the first one
#7
S36 = "Much of the dark atmosphere in Hedda Gabler comes from its themes of repression, manipulation, and existential despair."
#note: I didn't receive the answer in this format; I reformatted it by removing the initial part where Copilot said "Are you referring to Hedda Gabler by Henrik Ibsen? If so, "
#8
S36 = "Much of the dark atmosphere in Hedda Gabler stems from themes of repression, manipulation, and the protagonist’s intense dissatisfaction with her constrained existence."
#9
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the intense psychological tension woven throughout the play, as Hedda's manipulative behavior, suppressed desires, and existential dissatisfaction create a suffocating, almost claustrophobic mood."

#Gemini
#6
S36 = "Much of the dark atmosphere in gothic literature stems from themes of death, decay, the supernatural, and oppressive settings like ancient castles or desolate landscapes."
#7
S36 = "Much of the dark atmosphere in Hedda Gabler stems from Hedda's manipulative nature and her desire to control the lives of those around her, ultimately leading to tragedy."
#8
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the protagonist's internal conflicts, her manipulative nature, and the oppressive societal expectations placed upon women in the late 19th century."
#9
S36 = "Much of the dark atmosphere in Hedda Gabler stems from the characters' repressed desires, societal constraints, and the pervasive sense of disillusionment and entrapment."


#Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals its author's samurai ideals.
ah = "Please complete the following sentence: Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals its author's samurai ideals."

S37 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals its author's samurai ideals."

#ChatGPT
#6
S38 = "Chikamatsu Monzaemon's The Love Suicides at Amijima is a classic Japanese play that explores the conflict between duty and desire through the tragic story of two lovers."
#7
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki is a seminal work of Japanese bunraku puppet theater that poignantly explores the conflict between social obligation and personal desire through the tragic tale of two lovers driven to end their lives together."
#8
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals the intense emotional and societal pressures faced by individuals in a rigidly structured, 17th-century Japanese society, where love, honor, and the constraints of the class system intersect tragically."

#Copilot
#6
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki and The Love Suicides at Amijima are two of his most famous plays."
#note: includes reference
#7
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki is a jōruri (puppet theater) play first performed in 1703."
#8
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals the intense conflict between personal desires and societal expectations, illustrating how rigid social norms can lead to tragic consequences for individuals who defy them."
#note: includes references

#Gemini
#6
S38 = "'Chikamatsu Monzaemon's The Love Suicides at Sonezaki' is the full title of his famous Japanese puppet play (jōruri) written in 1703."
#7
S38 = "'Chikamatsu Monzaemon's The Love Suicides at Sonezaki' is a celebrated Japanese puppet play (jōruri) written in 1703 for the Takemoto-za theater in Osaka." 
#8
S38 = "Chikamatsu Monzaemon's The Love Suicides at Sonezaki reveals the tragic conflict between societal obligations and personal desires in feudal Japan, particularly the devastating consequences of forbidden love and the idealized pursuit of eternal union in death."


#Aristotle championed slavery, as did many Greeks of his day, as natural and just.
ah = "Please complete the following sentence: Aristotle championed slavery, as did many Greeks of his day, as natural and just."

S39 = "Aristotle championed slavery, as did many Greeks of his day, as natural and just."

#ChatGPT
#7
S40 = "Aristotle championed slavery, as did many Greeks of his time, believing it to be a natural and necessary institution for the functioning of society, particularly in his Politics, where he argued that some people were slaves by nature, destined to serve others."
#8
S40 = "Aristotle championed slavery, as did many Greeks of his time, believing it was a natural institution and that some people were born to be slaves, while others were destined to rule."
#9
S40 = "Aristotle championed slavery, as did many Greeks of his time, viewing it as a natural and necessary institution for the functioning of society."
#10
S40 = "Aristotle championed slavery, as did many Greeks of his day, believing it to be a natural and necessary institution for the functioning of society, arguing that some people were slaves by nature and that their subjugation was justified for the benefit of both the slaves and their masters."

#Copilot
#7
S40 = "Aristotle argued that some people were 'natural slaves,' meaning they were inherently suited to servitude due to their supposed lack of rational capacity."
#note: Copilot changed the first part of the sentence
#8
S40 = "Aristotle's views on slavery were complex and deeply tied to his philosophical framework."
#9
S40 = "Aristotle, like many Greeks of his time, argued that slavery was a natural institution, believing that some people were inherently suited to be slaves while others were naturally fit to rule."
#10
S40 = "Aristotle's views on slavery were complex and deeply tied to his philosophical framework."
#note: all included references

#Gemini
#7
S40 = "Aristotle championed slavery, as did many Greeks and this perspective, deeply embedded in the social and economic structures of the time, contrasts sharply with modern ethical views on human rights and equality."
#8
S40 = "Aristotle championed slavery, as did many Greeks of the ancient world."
#9
S40 = "Aristotle championed slavery, as did many Greeks of his era."
#10
S40 = "Aristotle championed slavery, as did many Greeks of his day, believing it to be a natural and necessary institution for the functioning of society, arguing that some individuals were inherently suited to be slaves while others were born to rule."

# %%
S39 = "Aristotle championed slavery, as did many Greeks of his day, as natural and just."

#ChatGPT
#7
S40 = "Aristotle championed slavery, as did many Greeks of his time, believing it to be a natural and necessary institution for the functioning of society, particularly in his Politics, where he argued that some people were slaves by nature, destined to serve others."
#8
S40 = "Aristotle championed slavery, as did many Greeks of his time, believing it was a natural institution and that some people were born to be slaves, while others were destined to rule."
#9
S40 = "Aristotle championed slavery, as did many Greeks of his time, viewing it as a natural and necessary institution for the functioning of society."
#10
S40 = "Aristotle championed slavery, as did many Greeks of his day, believing it to be a natural and necessary institution for the functioning of society, arguing that some people were slaves by nature and that their subjugation was justified for the benefit of both the slaves and their masters."

#Copilot
#7
S40 = "Aristotle argued that some people were 'natural slaves,' meaning they were inherently suited to servitude due to their supposed lack of rational capacity."
#note: Copilot changed the first part of the sentence
#8
S40 = "Aristotle's views on slavery were complex and deeply tied to his philosophical framework."
#9
S40 = "Aristotle, like many Greeks of his time, argued that slavery was a natural institution, believing that some people were inherently suited to be slaves while others were naturally fit to rule."
#10
S40 = "Aristotle's views on slavery were complex and deeply tied to his philosophical framework."
#note: all included references

#Gemini
#7
S40 = "Aristotle championed slavery, as did many Greeks and this perspective, deeply embedded in the social and economic structures of the time, contrasts sharply with modern ethical views on human rights and equality."
#8
S40 = "Aristotle championed slavery, as did many Greeks of the ancient world."
#9
S40 = "Aristotle championed slavery, as did many Greeks of his era."
#10
S40 = "Aristotle championed slavery, as did many Greeks of his day, believing it to be a natural and necessary institution for the functioning of society, arguing that some individuals were inherently suited to be slaves while others were born to rule."

# %%
S1_list = word_tokenize(S39)
S2_list = word_tokenize(S40)

sw = stopwords.words('english')
l1 = []
l2 = []

# %%
S1_set = {w for w in S1_list if not w in sw}
S2_set = {w for w in S2_list if not w in sw}

# %%
rvector = S1_set.union(S2_set)
for w in rvector:
    if w in S1_set:
        l1.append(1)
    else:
        l1.append(0)
    if w in S2_set:
        l2.append(1)
    else:
        l2.append(0)
c = 0

# %%
for i in range(len(rvector)):
    c+= l1[i]*l2[i]
cosine = c / float((sum(l1)*sum(l2))**0.5)
print("cosine similarity of the sentences: ", cosine)
# Out:
# cosine similarity of the sentences:  0.6396021490668313

# %%
flist = [0.7126966450997984, 0.5217491947499509, 0.8249579113843055]
avg20 = math.fsum(flist) / 3
print(avg20)
# Out:
# 0.6864679170780182

# %%
flist = [0.49099025303098287, 0.6666666666666666, 0.49099025303098287]
avg19 = math.fsum(flist) / 3
print(avg19)
# Out:
# 0.5495490575762108

# %%
flist = [0.6030226891555273, 0.5118906968889915, 0.5685352436149612]
avg18 = math.fsum(flist) / 3
print(avg18)
# Out:
# 0.5611495432198267

# %%
flist = [0.5809475019311126, 0.6123724356957945, 0.8164965809277261]
avg17 = math.fsum(flist) / 3
print(avg17)
# Out:
# 0.6699388395182111

# %%
flist = [0.5765566601970551, 0.6687338550904234, 0.6687338550904234]
avg16 = math.fsum(flist) / 3
print(avg16)
# Out:
# 0.6380081234593006

# %%
flist = [0.48666426339228763, 0.6123724356957946, 0.7216878364870323]
avg15 = math.fsum(flist) / 3
print(avg15)
# Out:
# 0.6069081785250382

# %%
flist = [0.6531972647421809, 0.6324555320336759, 0.6139406135149205]
avg14 = math.fsum(flist) / 3
print(avg14)
# Out:
# 0.6331978034302591

# %%
flist = [0.6837634587578276, 0.6546536707079772, 0.7171371656006361]
avg13 = math.fsum(flist) / 3
print(avg13)
# Out:
# 0.685184765022147

# %%
flist = [0.5263613559678152, 0.5017452060042544, 0.6963106238227914]
avg12 = math.fsum(flist) / 3
print(avg12)
# Out:
# 0.574805728598287

# %%
flist = [1.0, 0.7001400420140048, 0.8333333333333334]
avg11 = math.fsum(flist) / 3
print(avg11)
# Out:
# 0.8444911251157793

# %%
flist = [0.8563488385776753, 0.7237468644557459, 0.9198662110077999]
avg10 = math.fsum(flist) / 3
print(avg10)
# Out:
# 0.8333206380137405

# %%
flist = [0.7669649888473704, 0.816496580927726, 0.8215838362577491]
avg9 = math.fsum(flist) / 3
print(avg9)
# Out:
# 0.8016818020109485

# %%
flist = [0.6999132392733555, 0.5726562866782, 0.6240377207533828]
avg8 = math.fsum(flist) / 3
print(avg8)
# Out:
# 0.6322024155683127

# %%
flist = [0.8401680504168059, 0.9607689228305227, 0.8944271909999159]
avg7 = math.fsum(flist) / 3
print(avg7)
# Out:
# 0.8984547214157481

# %%
flist = [0.7126966450997984, 1.0, 0.8432740427115678]
avg6 = math.fsum(flist) / 3
print(avg6)
# Out:
# 0.8519902292704554

# %%
flist = [0.7252406676228422, 0.7252406676228422, 0.6689936080056726]
avg5 = math.fsum(flist) / 3
print(avg5)
# Out:
# 0.7064916477504525

# %%
flist = [0.6864064729836442, 0.6666666666666666, 0.6123724356957946]
avg4 = math.fsum(flist) / 3
print(avg4)
# Out:
# 0.6551485251153685

# %%
flist = [0.6529286250990105, 0.6708203932499369, 0.9128709291752769]
avg3 = math.fsum(flist) / 3
print(avg3)
# Out:
# 0.7455399825080748

# %%
flist = [0.760885910252682, 0.753778361444409, 0.7526178090063816]
avg2 = math.fsum(flist) / 3
print(avg2)
# Out:
# 0.7557606935678242

# %%
flist = [0.816496580927726, 0.816496580927726, 0.816496580927726]
avg1 = math.fsum(flist) / 3
print(avg1)
# Out:
# 0.8164965809277259

# %%
flist = [0.6227991553292184, 0.6963106238227914, 0.8528028654224417]
avg0 = math.fsum(flist) / 3
print(avg0)
# Out:
# 0.7239708815248171

# %%
flist = [0.7035264706814485, 0.7035264706814485, 0.7035264706814485]
avg21 = math.fsum(flist) / 3
print(avg21)
# Out:
# 0.7035264706814485

# %% [markdown]
# Aristotle slavery max
# ChatGPT:
# cosine similarity of the sentences:  0.7126966450997984
#
# Copilot:
# cosine similarity of the sentences:  0.5217491947499509
#
# Gemini:
# cosine similarity of the sentences:  0.8249579113843055
#
# The Love Suicides at Sonezaki max
# ChatGPT:
# cosine similarity of the sentences:  0.49099025303098287
#
# Copilot:
# cosine similarity of the sentences:  0.6666666666666666
#
# Gemini:
# cosine similarity of the sentences:  0.49099025303098287
#
# Hedda Gabler max
# ChatGPT:
# cosine similarity of the sentences:  0.6030226891555273
#
# Copilot:
# cosine similarity of the sentences:  0.5118906968889915
#
# Gemini:
# cosine similarity of the sentences:  0.5685352436149612
#
#
# Laptops and Smart Phones max
# ChatGPT:
# cosine similarity of the sentences:  0.5809475019311126
#
# Copilot:
# cosine similarity of the sentences:  0.6123724356957945
#
# Gemini:
# cosine similarity of the sentences:  0.8164965809277261
#
# 'Life of Leonardo' max
# ChatGPT:
# cosine similarity of the sentences:  0.5765566601970551
#
# Copilot:
# cosine similarity of the sentences:  0.6687338550904234
#
# Gemini:
# cosine similarity of the sentences:  0.6687338550904234
#
# Memristors max
# ChatGPT:
# cosine similarity of the sentences:  0.48666426339228763
#
# Copilot:
# cosine similarity of the sentences:  0.6123724356957946
#
# Gemini:
# cosine similarity of the sentences:  0.7216878364870323
#
# English dialects max
# ChatGPT:
# cosine similarity of the sentences:  0.6531972647421809
#
# Copilot:
# cosine similarity of the sentences:  0.6324555320336759
#
# Gemini:
# cosine similarity of the sentences:  0.6139406135149205
#
# COBOL max
# ChatGPT:
# cosine similarity of the sentences:  0.6837634587578276
#
# Copilot:
# cosine similarity of the sentences:  0.6546536707079772
#
# Gemini:
# cosine similarity of the sentences:  0.7171371656006361
#
# YouTube max
# ChatGPT:
# cosine similarity of the sentences:  0.5263613559678152
#
# Copilot:
# cosine similarity of the sentences:  0.5017452060042544
#
# Gemini:
# cosine similarity of the sentences:  0.6963106238227914
#
#
# LG max
# ChatGPT:
# cosine similarity of the sentences:  1.0
# note: both of the outputs with references had high cosine similarities
#
# Copilot:
# cosine similarity of the sentences:  0.7001400420140048
# note: always changed or removed some of the initial words
#
# Gemini:
# cosine similarity of the sentences:  0.8333333333333334
#
# Cognitive Behavioral Therapy max
# ChatGPT:
# cosine similarity of the sentences:  0.8563488385776753
#
# Copilot:
# cosine similarity of the sentences:  0.7237468644557459
#
# Gemini:
# cosine similarity of the sentences:  0.9198662110077999
#
# Inflation max
# ChatGPT:
# cosine similarity of the sentences:  0.7669649888473704
#
# Copilot:
# cosine similarity of the sentences:  0.816496580927726
#
# Gemini:
# cosine similarity of the sentences:  0.8215838362577491
#
#
# van Gogh max
# ChatGPT:
# cosine similarity of the sentences:  0.6999132392733555
#
# Copilot:
# cosine similarity of the sentences:  0.5726562866782
#
# Gemini:
# cosine similarity of the sentences:  0.6240377207533828
#
# Amazon River max
# ChatGPT:
# cosine similarity of the sentences:  0.8401680504168059
#
# Copilot:
# cosine similarity of the sentences:  0.9607689228305227
#
# Gemini:
# cosine similarity of the sentences:  0.8944271909999159
#
# Beethoven max
# ChatGPT:
# cosine similarity of the sentences:  0.7126966450997984
#
# Copilot:
# cosine similarity of the sentences:  1.0
#
# Gemini:
# cosine similarity of the sentences:  0.8432740427115678
#
# Hamlet max
# ChatGPT:
# cosine similarity of the sentences:  0.7252406676228422
#
# Copilot:
# cosine similarity of the sentences:  0.7252406676228422
#
# Gemini:
# cosine similarity of the sentences:  0.6689936080056726
#
# Photosynthesis max
# ChatGPT:
# cosine similarity of the sentences:  0.6864064729836442
#
# Copilot:
# cosine similarity of the sentences:  0.6666666666666666
#
# Gemini:
# cosine similarity of the sentences:  0.6123724356957946
#
# Artificial Intelligence max
# chatGPT:
# cosine similarity of the sentences:  0.6529286250990105
#
# Copilot:
# cosine similarity of the sentences:  0.6708203932499369
#
# Gemini:
# cosine similarity of the sentences:  0.9128709291752769
#
# Great Wall of China max
# chatGPT:
# cosine similarity of the sentences:  0.760885910252682
#
# Copilot:
# cosine similarity of the sentences:  0.753778361444409
#
# Gemini:
# cosine similarity of the sentences:  0.7526178090063816
#
# Jupiter max
# chatGPT:
# cosine similarity of the sentences:  0.816496580927726
#
# Copilot:
# cosine similarity of the sentences:  0.816496580927726
#
# Gemini:
# cosine similarity of the sentences:  0.816496580927726
#
#
# #cardinals
# #ChatGPT
# #10: cosine similarity of the sentences:  0.6227991553292184
#
# #Copilot (currently using the whole output, not just the 1st sentence)
# #7: cosine similarity of the sentences:  0.4090909090909091
# #8: cosine similarity of the sentences:  0.37670528747840887
# #9: cosine similarity of the sentences:  0.4136701519960153
# #Copilot just first sentence
# #7: cosine similarity of the sentences:  0.5853694070049635
# #8: cosine similarity of the sentences:  0.6963106238227914
# #9: cosine similarity of the sentences:  0.6030226891555273
# #10: cosine similarity of the sentences:  0.5850179393017045
#
#  Gemini
# #7: cosine similarity of the sentences:  0.6784005252999682
#  8: cosine similarity of the sentences: 0.8528028654224417
#  9: cosine similarity of the sentences:  0.7106690545187014
#  10: cosine similarity of the sentences:  0.5698028822981898
#
# #employee on vacation
#
# #ChatGPT
# #7: cosine similarity of the sentences:  0.4811252243246881
# #8: cosine similarity of the sentences:  0.502518907629606
# #9: cosine similarity of the sentences:  0.5773502691896257
# #10: cosine similarity of the sentences:  0.7035264706814485
#
# #Copilot
# #7: cosine similarity of the sentences:  0.5892556509887896
# #8: cosine similarity of the sentences:  0.4166666666666667
# #9: cosine similarity of the sentences:  0.5
# #10: cosine similarity of the sentences:  0.7035264706814485
#
# #Gemini
# #7: cosine similarity of the sentences:  0.5555555555555556
# #8: cosine similarity of the sentences:  0.502518907629606
# #9: cosine similarity of the sentences:  0.6324555320336759
# #10: cosine similarity of the sentences:  0.7035264706814485

# %%
scores = [avg0, avg1, avg2, avg3, avg4, avg5, avg6, avg7, avg8, avg9, avg10, avg11, avg12, avg13, avg14, avg15, avg16, avg17, avg18, avg19, avg20, avg21]

# %%
# i is the upper end of human-written and the lower end of medium confidence LLM-written, j is the upper end of medium confidence
# LLM-written and the lower end of high confidence LLM-written
i = 0.0
best = 0
best_i = 0.0
best_j = 0.0
while i < 1:
    j = i
    while j < 1:
        current_s = 0
        for k in range(0,len(scores)-1):
                if k < 11 and scores[k] >= j:
                    current_s = current_s + 2
                elif k < 11 and scores[k] < i:
                    current_s = current_s - 1
                elif k >= 11 and scores[k] >= j:
                    current_s = current_s - 5
                elif k >= 11 and scores[k] < i:
                    current_s = current_s + 3
                elif k < 11 and scores[k] >= i and scores[k] < j:
                    current_s = current_s + 2
                elif k >= 11 and scores[k] >= i and scores[k] < j:
                    current_s = current_s - 2
        if current_s > best:
            best = current_s
            best_i = i
            best_j = j
        j = j + 0.01
    i = i + 0.01

print(best)
print(best_i)
print(best_j)
# Out:
# 41
# 0.6900000000000004
# 0.8500000000000005
